# %% [markdown]
# # Stage 4: Advanced Analysis
# - Sentiment Analysis
# - Text Classification

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

from transformers import pipeline

# %% [markdown]
# ### Files Import

# %%
data = pd.read_pickle('data_clean_summarized.pkl')
data.reset_index(drop=True, inplace=True)

data
# Out:
#                                                    text  rating  \
# 0      My boyfriend bought this for our house and ou...       1
# 1      This is a good small microwave for someone in...       5
# 2      This microwave is not powerful and heats food...       1
# 3      My mother has Macular Degeneration Disease Th...       5
# 4      This microwave has been barely used at all an...       1
# ...                                                 ...     ...
# 3862    I love this thing mostly cuz it came with Alexa       4
# 3863   This microwave has stopped working everytime ...       5
# 3864   Alexa stopped working on the microwave a week...       1
# 3865   I received this as a Christmas gift and absol...       5
# 3866   The plastic is coming up on the key pad I jus...       3
#
#                                                 summary
# 0
# 1     This is a good small microwave for someone in ...
# 2     This microwave is not powerful and heats food ...
# 3     My mother has Macular Degeneration Disease Thi...
# 4     This microwave has been barely used at all and...
# ...                                                 ...
# 3862    I love this thing mostly cuz it came with Alexa
# 3863  This microwave has stopped working everytime w...
# 3864  Alexa stopped working on the microwave a week ...
# 3865  I received this as a Christmas gift and absolu...
# 3866  The plastic is coming up on the key pad I just...
#
# [3867 rows x 3 columns]

# %%
# from Amazon website (https://www.amazon.com/AmazonBasics-Microwave-Small-Works-Alexa/dp/B07894S727)
specs = pd.read_csv("specs.csv")
specifications = list(specs["Specifications"])                  # extract specifications headers from specs.csv

# from Mr Right Ideas website (https://www.mrright.in/ideas/appliances/microwave/microwave-oven-components-and-their-functions/)
comps = pd.read_csv("comps.csv")
components = list(dict.fromkeys(comps["Components"]))           # extract component headers from comps.csv
comps_renamed = list(dict.fromkeys(comps["Comps_renamed"]))     # extract renamed components from comps.csv

# from wiki_scraper.py
wiki_adjusted = pd.read_csv("wiki_adjusted.csv")
wiki_adjusted = list(wiki_adjusted['Keywords'])                 # extract sustainability keywords from wiki_adjusted.csv

others = ['Packaging', 'Delivery']
specifications += others

data['comps_mention'] = 'na'

# %% [markdown]
# ### Components Mentioned in Reviews
# - With Sentiment Analysis

# %%
for i in range(data.shape[0]):
    for j in comps_renamed:
        if j in data['text'][i]:
            data['comps_mention'][i] = j

data
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3940\526069652.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['comps_mention'][i] = j
#                                                    text  rating  \
# 0      My boyfriend bought this for our house and ou...       1
# 1      This is a good small microwave for someone in...       5
# 2      This microwave is not powerful and heats food...       1
# 3      My mother has Macular Degeneration Disease Th...       5
# 4      This microwave has been barely used at all an...       1
# ...                                                 ...     ...
# 3862    I love this thing mostly cuz it came with Alexa       4
# 3863   This microwave has stopped working everytime ...       5
# 3864   Alexa stopped working on the microwave a week...       1
# 3865   I received this as a Christmas gift and absol...       5
# 3866   The plastic is coming up on the key pad I jus...       3
#
#                                                 summary comps_mention
# 0                                                               panel
# 1     This is a good small microwave for someone in ...            na
# 2     This microwave is not powerful and heats food ...            na
# 3     My mother has Macular Degeneration Disease Thi...            na
# 4     This microwave has been barely used at all and...            na
# ...                                                 ...           ...
# 3862    I love this thing mostly cuz it came with Alexa            na
# 3863  This microwave has stopped working everytime w...            na
# 3864  Alexa stopped working on the microwave a week ...            na
# 3865  I received this as a Christmas gift and absolu...            na
# 3866  The plastic is coming up on the key pad I just...            na
#
# [3867 rows x 4 columns]

# %%
# Create quick lambda functions to find the polarity and subjectivity of each routine
from textblob import TextBlob

count_result = []
for comps in comps_renamed:
    count = [data[data.comps_mention == comps].shape[0]]
    count_result += count

pol = lambda x: TextBlob(x).sentiment.polarity
data['polarity'] = data['summary'].apply(pol)

pol_count  = lambda x: 1  if x > 0 else -1
data['pol_count'] = data['polarity'].apply(pol_count)
display(data)

sentiment_list = []
for comps in comps_renamed:
    data_count = data[data.comps_mention == comps]
    sen_ana = data_count['pol_count'].sum()
    if sen_ana > 0:
        sen_ana = 'positive'
    else:
        sen_ana = 'negative'
    sentiment_list += [sen_ana]
    # df_chart['sentiments'] = [df_chart['labels'] == comps]

# data['pol_count'].sum()

chart = {'labels': comps_renamed,
        'values': count_result,
        'sentiments': sentiment_list}

df_chart = pd.DataFrame(chart, columns=['labels','values', 'sentiments'])

df_chart
# Out:
#                                                    text  rating  \
# 0      My boyfriend bought this for our house and ou...       1
# 1      This is a good small microwave for someone in...       5
# 2      This microwave is not powerful and heats food...       1
# 3      My mother has Macular Degeneration Disease Th...       5
# 4      This microwave has been barely used at all an...       1
# ...                                                 ...     ...
# 3862    I love this thing mostly cuz it came with Alexa       4
# 3863   This microwave has stopped working everytime ...       5
# 3864   Alexa stopped working on the microwave a week...       1
# 3865   I received this as a Christmas gift and absol...       5
# 3866   The plastic is coming up on the key pad I jus...       3
#
#                                                 summary comps_mention  \
# 0                                                               panel
# 1     This is a good small microwave for someone in ...            na
# 2     This microwave is not powerful and heats food ...            na
# 3     My mother has Macular Degeneration Disease Thi...            na
# 4     This microwave has been barely used at all and...            na
# ...                                                 ...           ...
# 3862    I love this thing mostly cuz it came with Alexa            na
# 3863  This microwave has stopped working everytime w...            na
# 3864  Alexa stopped working on the microwave a week ...            na
# 3865  I received this as a Christmas gift and absolu...            na
# 3866  The plastic is coming up on the key pad I just...            na
#
#       polarity  pol_count
# 0     0.000000         -1
# 1     0.225000          1
# 2     0.050000          1
# 3     0.312500          1
# 4    -0.216667         -1
# ...        ...        ...
# 3862  0.500000          1
# 3863  0.000000         -1
# 3864  0.000000         -1
# 3865  0.243750          1
# 3866  0.100000          1
#
# [3867 rows x 6 columns]
#          labels  values sentiments
# 0   transformer       0   negative
# 1     magnetron       1   negative
# 2     waveguide       3   negative
# 3           fan      26   positive
# 4          case      18   positive
# 5     turntable      42   positive
# 6         panel      51   positive
# 7        socket       1   positive
# 8         alexa     154   positive
# 9          door     123   positive
# 10       handle      18   positive

# %%
# Data check

data_selected = data[data.comps_mention == df_chart.labels[2]] # check number accordingly
data_selected.reset_index(drop=True, inplace=True)

data_selected
# Out:
#                                                 text  rating  \
# 0   I had this microwave for less than a year and...       1
# 1   Disclaimer We have had this microwave for abo...       1
# 2   Broke only after a few months of use It looks...       1
#
#                                              summary comps_mention  polarity  \
# 0  I had this microwave for less than a year and ...     waveguide -0.059028
# 1  Disclaimer We have had this microwave for abou...     waveguide  0.195833
# 2  Broke only after a few months of use It looks ...     waveguide -0.100000
#
#    pol_count
# 0         -1
# 1          1
# 2         -1

# %% [markdown]
# ### Sustainability Mentioned in Reviews
# - With Sentiment Analysis

# %%
data['sus_mention'] = 'na'
wiki_adjusted = ['waste', 'eneryg', 'environmental', 'material']
for i in range(data.shape[0]):
    for j in wiki_adjusted:
        if j in data['text'][i]:
            data['sus_mention'][i] = j

data
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3940\2510467673.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sus_mention'][i] = j
#                                                    text  rating  \
# 0      My boyfriend bought this for our house and ou...       1
# 1      This is a good small microwave for someone in...       5
# 2      This microwave is not powerful and heats food...       1
# 3      My mother has Macular Degeneration Disease Th...       5
# 4      This microwave has been barely used at all an...       1
# ...                                                 ...     ...
# 3862    I love this thing mostly cuz it came with Alexa       4
# 3863   This microwave has stopped working everytime ...       5
# 3864   Alexa stopped working on the microwave a week...       1
# 3865   I received this as a Christmas gift and absol...       5
# 3866   The plastic is coming up on the key pad I jus...       3
#
#                                                 summary comps_mention  \
# 0                                                               panel
# 1     This is a good small microwave for someone in ...            na
# 2     This microwave is not powerful and heats food ...            na
# 3     My mother has Macular Degeneration Disease Thi...            na
# 4     This microwave has been barely used at all and...            na
# ...                                                 ...           ...
# 3862    I love this thing mostly cuz it came with Alexa            na
# 3863  This microwave has stopped working everytime w...            na
# 3864  Alexa stopped working on the microwave a week ...            na
# 3865  I received this as a Christmas gift and absolu...            na
# 3866  The plastic is coming up on the key pad I just...            na
#
#       polarity  pol_count sus_mention
# 0     0.000000         -1          na
# 1     0.225000          1          na
# 2     0.050000          1          na
# 3     0.312500          1          na
# 4    -0.216667         -1          na
# ...        ...        ...         ...
# 3862  0.500000          1          na
# 3863  0.000000         -1          na
# 3864  0.000000         -1          na
# 3865  0.243750          1          na
# 3866  0.100000          1          na
#
# [3867 rows x 7 columns]

# %%
# Create quick lambda functions to find the polarity and subjectivity of each routine
from textblob import TextBlob

count_result = []
for sus in wiki_adjusted:
    count = [data[data.sus_mention == sus].shape[0]]
    count_result += count

pol = lambda x: TextBlob(x).sentiment.polarity
data['polarity'] = data['summary'].apply(pol)

pol_count  = lambda x: 1  if x > 0 else -1
data['pol_count'] = data['polarity'].apply(pol_count)
display(data)

sentiment_list = []
for sus in wiki_adjusted:
    data_count = data[data.sus_mention == sus]
    sen_ana = data_count['pol_count'].sum()
    if sen_ana > 0:
        sen_ana = 'positive'
    else:
        sen_ana = 'negative'
    sentiment_list += [sen_ana]
    # df_chart['sentiments'] = [df_chart['labels'] == comps]

# data['pol_count'].sum()

chart = {'labels': wiki_adjusted,
        'values': count_result,
        'sentiments': sentiment_list}

df_chart = pd.DataFrame(chart, columns=['labels','values', 'sentiments'])

df_chart
# Out:
#                                                    text  rating  \
# 0      My boyfriend bought this for our house and ou...       1
# 1      This is a good small microwave for someone in...       5
# 2      This microwave is not powerful and heats food...       1
# 3      My mother has Macular Degeneration Disease Th...       5
# 4      This microwave has been barely used at all an...       1
# ...                                                 ...     ...
# 3862    I love this thing mostly cuz it came with Alexa       4
# 3863   This microwave has stopped working everytime ...       5
# 3864   Alexa stopped working on the microwave a week...       1
# 3865   I received this as a Christmas gift and absol...       5
# 3866   The plastic is coming up on the key pad I jus...       3
#
#                                                 summary comps_mention  \
# 0                                                               panel
# 1     This is a good small microwave for someone in ...            na
# 2     This microwave is not powerful and heats food ...            na
# 3     My mother has Macular Degeneration Disease Thi...            na
# 4     This microwave has been barely used at all and...            na
# ...                                                 ...           ...
# 3862    I love this thing mostly cuz it came with Alexa            na
# 3863  This microwave has stopped working everytime w...            na
# 3864  Alexa stopped working on the microwave a week ...            na
# 3865  I received this as a Christmas gift and absolu...            na
# 3866  The plastic is coming up on the key pad I just...            na
#
#       polarity  pol_count sus_mention
# 0     0.000000         -1          na
# 1     0.225000          1          na
# 2     0.050000          1          na
# 3     0.312500          1          na
# 4    -0.216667         -1          na
# ...        ...        ...         ...
# 3862  0.500000          1          na
# 3863  0.000000         -1          na
# 3864  0.000000         -1          na
# 3865  0.243750          1          na
# 3866  0.100000          1          na
#
# [3867 rows x 7 columns]
#           labels  values sentiments
# 0          waste      63   negative
# 1         eneryg       0   negative
# 2  environmental       1   positive
# 3       material       1   positive

# %%
# Data check

data_selected = data[data.comps_mention == df_chart.labels[2]] # check number accordingly
data_selected.reset_index(drop=True, inplace=True)

data_selected
# Out:
# Empty DataFrame
# Columns: [text, rating, summary, comps_mention, polarity, pol_count, sus_mention]
# Index: []

# %% [markdown]
# ## Zero-Shot-Classification

# %%
classifier = pipeline("zero-shot-classification", device=0)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)

# %% [markdown]
# ### Specification Categorization
# - With Sentiment Analysis

# %%
display(specifications)
#Applying it into the dataframe base on original review
data['category'] = data['text'].apply(lambda x: classifier(x, candidate_labels=specifications))

data
# Out:
# ['Power',
#  'Interior',
#  'Levels',
#  'Dimensions',
#  'Technology',
#  'Weight',
#  'Durability',
#  'Packaging',
#  'Delivery']
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                                    text  rating  \
# 0      My boyfriend bought this for our house and ou...       1
# 1      This is a good small microwave for someone in...       5
# 2      This microwave is not powerful and heats food...       1
# 3      My mother has Macular Degeneration Disease Th...       5
# 4      This microwave has been barely used at all an...       1
# ...                                                 ...     ...
# 3862    I love this thing mostly cuz it came with Alexa       4
# 3863   This microwave has stopped working everytime ...       5
# 3864   Alexa stopped working on the microwave a week...       1
# 3865   I received this as a Christmas gift and absol...       5
# 3866   The plastic is coming up on the key pad I jus...       3
#
#                                                 summary comps_mention  \
# 0                                                               panel
# 1     This is a good small microwave for someone in ...            na
# 2     This microwave is not powerful and heats food ...            na
# 3     My mother has Macular Degeneration Disease Thi...            na
# 4     This microwave has been barely used at all and...            na
# ...                                                 ...           ...
# 3862    I love this thing mostly cuz it came with Alexa            na
# 3863  This microwave has stopped working everytime w...            na
# 3864  Alexa stopped working on the microwave a week ...            na
# 3865  I received this as a Christmas gift and absolu...            na
# 3866  The plastic is coming up on the key pad I just...            na
#
#       polarity  pol_count sus_mention  \
# 0     0.000000         -1          na
# 1     0.225000          1          na
# 2     0.050000          1          na
# 3     0.312500          1          na
# 4    -0.216667         -1          na
# ...        ...        ...         ...
# 3862  0.500000          1          na
# 3863  0.000000         -1          na
# 3864  0.000000         -1          na
# 3865  0.243750          1          na
# 3866  0.100000          1          na
#
#                                                category
# 0     {'sequence': ' My boyfriend bought this for ou...
# 1     {'sequence': ' This is a good small microwave ...
# 2     {'sequence': ' This microwave is not powerful ...
# 3     {'sequence': ' My mother has Macular Degenerat...
# 4     {'sequence': ' This microwave has been barely ...
# ...                                                 ...
# 3862  {'sequence': ' I love this thing mostly cuz it...
# 3863  {'sequence': ' This microwave has stopped work...
# 3864  {'sequence': ' Alexa stopped working on the mi...
# 3865  {'sequence': ' I received this as a Christmas ...
# 3866  {'sequence': ' The plastic is coming up on the...
#
# [3867 rows x 8 columns]

# %%
#Replacing the category with the top matched category
for i in tqdm(range(data.shape[0])):
    if data['category'][i] not in specifications:
        data['category'][i] = data['category'][i].get('labels')[0]
# Out:
#   0%|          | 0/3867 [00:00<?, ?it/s]C:\Users\User\AppData\Local\Temp\ipykernel_3940\387916688.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['category'][i] = data['category'][i].get('labels')[0]
# 100%|██████████| 3867/3867 [00:30<00:00, 126.73it/s]

# %%
data_cat = data.copy()

# %%
candidate_results = list(0 for i in range(len(specifications)))


def count(category):
    for i in range(len(specifications)):
        if category == specifications[i]:
            candidate_results[i] = candidate_results[i] + 1

# %%
# Run the counting function
data_cat['category'].apply(lambda x: count(x))

candidate_results
# Out:
# [413, 688, 25, 68, 1995, 43, 530, 23, 82]

# %%
sentiment_list_func = []
for func in specifications:
    data_count = data[data.category == func]
    sen_ana = data_count['pol_count'].sum()
    if sen_ana > 0:
        sen_ana = 'positive'
    else:
        sen_ana = 'negative'
    sentiment_list_func += [sen_ana]
    # df_chart['sentiments'] = [df_chart['labels'] == comps]

# data['pol_count'].sum()

chart = {'labels': specifications,
        'values': candidate_results,
        'sentiments': sentiment_list_func}

df_chart = pd.DataFrame(chart, columns=['labels','values', 'sentiments'])

df_chart
# Out:
#        labels  values sentiments
# 0       Power     413   positive
# 1    Interior     688   positive
# 2      Levels      25   negative
# 3  Dimensions      68   positive
# 4  Technology    1995   positive
# 5      Weight      43   positive
# 6  Durability     530   positive
# 7   Packaging      23   positive
# 8    Delivery      82   positive

# %% [markdown]
# ### Sustainability Categorization
# - Sentiment Analysis included

# %%
#Categorying in terms of sustainability

#Applying it into the dataframe base on original review
data['sus_category'] = data['text'].apply(lambda x: classifier(x, candidate_labels=wiki_adjusted))

data
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:996: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                                    text  rating  \
# 0      My boyfriend bought this for our house and ou...       1
# 1      This is a good small microwave for someone in...       5
# 2      This microwave is not powerful and heats food...       1
# 3      My mother has Macular Degeneration Disease Th...       5
# 4      This microwave has been barely used at all an...       1
# ...                                                 ...     ...
# 3862    I love this thing mostly cuz it came with Alexa       4
# 3863   This microwave has stopped working everytime ...       5
# 3864   Alexa stopped working on the microwave a week...       1
# 3865   I received this as a Christmas gift and absol...       5
# 3866   The plastic is coming up on the key pad I jus...       3
#
#                                                 summary comps_mention  \
# 0                                                               panel
# 1     This is a good small microwave for someone in ...            na
# 2     This microwave is not powerful and heats food ...            na
# 3     My mother has Macular Degeneration Disease Thi...            na
# 4     This microwave has been barely used at all and...            na
# ...                                                 ...           ...
# 3862    I love this thing mostly cuz it came with Alexa            na
# 3863  This microwave has stopped working everytime w...            na
# 3864  Alexa stopped working on the microwave a week ...            na
# 3865  I received this as a Christmas gift and absolu...            na
# 3866  The plastic is coming up on the key pad I just...            na
#
#       polarity  pol_count sus_mention    category  \
# 0     0.000000         -1          na  Technology
# 1     0.225000          1          na  Technology
# 2     0.050000          1          na       Power
# 3     0.312500          1          na  Technology
# 4    -0.216667         -1          na    Interior
# ...        ...        ...         ...         ...
# 3862  0.500000          1          na  Technology
# 3863  0.000000         -1          na    Interior
# 3864  0.000000         -1          na  Technology
# 3865  0.243750          1          na  Technology
# 3866  0.100000          1          na  Technology
#
#                                            sus_category
# 0     {'sequence': ' My boyfriend bought this for ou...
# 1     {'sequence': ' This is a good small microwave ...
# 2     {'sequence': ' This microwave is not powerful ...
# 3     {'sequence': ' My mother has Macular Degenerat...
# 4     {'sequence': ' This microwave has been barely ...
# ...                                                 ...
# 3862  {'sequence': ' I love this thing mostly cuz it...
# 3863  {'sequence': ' This microwave has stopped work...
# 3864  {'sequence': ' Alexa stopped working on the mi...
# 3865  {'sequence': ' I received this as a Christmas ...
# 3866  {'sequence': ' The plastic is coming up on the...
#
# [3867 rows x 9 columns]

# %%
#Replacing the category with the top matched category
for i in tqdm(range(data.shape[0])):
    if data['sus_category'][i] not in wiki_adjusted:
        data['sus_category'][i] = data['sus_category'][i].get('labels')[0]
# Out:
#   0%|          | 0/3867 [00:00<?, ?it/s]C:\Users\User\AppData\Local\Temp\ipykernel_3940\926357156.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sus_category'][i] = data['sus_category'][i].get('labels')[0]
# 100%|██████████| 3867/3867 [00:30<00:00, 128.14it/s]

# %%
data_cat = data.copy()

candidate_results = list(0 for i in range(len(wiki_adjusted)))


def count(category):
    for i in range(len(wiki_adjusted)):
        if category == wiki_adjusted[i]:
            candidate_results[i] = candidate_results[i] + 1

# %%
# Run the counting function
data_cat['sus_category'].apply(lambda x: count(x))

candidate_results
# Out:
# [307, 2358, 5, 1197]

# %%
sentiment_list_func = []
for func in wiki_adjusted:
    data_count = data[data.category == func]
    sen_ana = data_count['pol_count'].sum()
    if sen_ana > 0:
        sen_ana = 'positive'
    else:
        sen_ana = 'negative'
    sentiment_list_func += [sen_ana]
    # df_chart['sentiments'] = [df_chart['labels'] == comps]

# data['pol_count'].sum()

chart = {'labels': wiki_adjusted,
        'values': candidate_results,
        'sentiments': sentiment_list_func}

df_chart = pd.DataFrame(chart, columns=['labels','values', 'sentiments'])

df_chart
# Out:
#           labels  values sentiments
# 0          waste     307   negative
# 1         eneryg    2358   negative
# 2  environmental       5   negative
# 3       material    1197   negative

# %%
data.to_pickle('data_analysed.pkl')

data
# Out:
#                                                    text  rating  \
# 0      My boyfriend bought this for our house and ou...       1
# 1      This is a good small microwave for someone in...       5
# 2      This microwave is not powerful and heats food...       1
# 3      My mother has Macular Degeneration Disease Th...       5
# 4      This microwave has been barely used at all an...       1
# ...                                                 ...     ...
# 3862    I love this thing mostly cuz it came with Alexa       4
# 3863   This microwave has stopped working everytime ...       5
# 3864   Alexa stopped working on the microwave a week...       1
# 3865   I received this as a Christmas gift and absol...       5
# 3866   The plastic is coming up on the key pad I jus...       3
#
#                                                 summary comps_mention  \
# 0                                                               panel
# 1     This is a good small microwave for someone in ...            na
# 2     This microwave is not powerful and heats food ...            na
# 3     My mother has Macular Degeneration Disease Thi...            na
# 4     This microwave has been barely used at all and...            na
# ...                                                 ...           ...
# 3862    I love this thing mostly cuz it came with Alexa            na
# 3863  This microwave has stopped working everytime w...            na
# 3864  Alexa stopped working on the microwave a week ...            na
# 3865  I received this as a Christmas gift and absolu...            na
# 3866  The plastic is coming up on the key pad I just...            na
#
#       polarity  pol_count sus_mention    category sus_category
# 0     0.000000         -1          na  Technology       eneryg
# 1     0.225000          1          na  Technology     material
# 2     0.050000          1          na       Power     material
# 3     0.312500          1          na  Technology     material
# 4    -0.216667         -1          na    Interior       eneryg
# ...        ...        ...         ...         ...          ...
# 3862  0.500000          1          na  Technology     material
# 3863  0.000000         -1          na    Interior       eneryg
# 3864  0.000000         -1          na  Technology     material
# 3865  0.243750          1          na  Technology     material
# 3866  0.100000          1          na  Technology     material
#
# [3867 rows x 9 columns]
